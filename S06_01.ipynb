# %% [markdown]
# # Modelos Theta y 4Theta

# %%
# instalar libreria darts para series de tiempo 
# https://pypi.org/project/darts/


# !pip install darts

# %% [markdown]
# # Modelos Theta

# %%
# 
# import os, sys
# from google.colab import drive
# drive.mount('/content/mnt', force_remount=True)
# nb_path = '/content/notebooks'
# os.symlink('/content/mnt/My Drive/Colab Notebooks/Librerias', nb_path)
# #sys.path.insert(0, nb_path)  # or append(nb_path)
# sys.path.append(nb_path)  # or append(nb_path)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Es necesario tener instalado DARTS
#
# [Darts: https://unit8co.github.io/darts/index.html](https://unit8co.github.io/darts/index.html)

# %%
#!pip install darts

# %%
# Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - Utilizamos la libreria **darts**
# - Seleccionamos los datos de Lineas aereas

# %%
# %%
from darts import TimeSeries
from darts.datasets import AirPassengersDataset

# %% [markdown]
# - **Grafico de la Serie Temporal de lineas aereas**

# %%
# %%
series = AirPassengersDataset().load()
series
# Out:
# <TimeSeries (DataArray) (Month: 144, component: 1, sample: 1)> Size: 1kB
# array([[[112.]],
#
#        [[118.]],
#
#        [[132.]],
#
#        [[129.]],
#
#        [[121.]],
#
#        [[135.]],
#
#        [[148.]],
#
#        [[148.]],
#
#        [[136.]],
#
#        [[119.]],
#
# ...
#
#        [[419.]],
#
#        [[461.]],
#
#        [[472.]],
#
#        [[535.]],
#
#        [[622.]],
#
#        [[606.]],
#
#        [[508.]],
#
#        [[461.]],
#
#        [[390.]],
#
#        [[432.]]])
# Coordinates:
#   * Month      (Month) datetime64[ns] 1kB 1949-01-01 1949-02-01 ... 1960-12-01
#   * component  (component) object 8B '#Passengers'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %%
#import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (12,6)
series.plot()
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# - Diferentes formas de seleccionat TRAIN y TEST

# %% [markdown]
# ```
# split_before
# ```

# %%
# %%
series1, series2 = series.split_before(0.75) # 75% train, 25% test
series1.plot()
series2.plot()
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# - Con el número de observaciones

# %%
# %%
series1, series2 = series[:-36], series[-36:] #cojo los ultimos 36 meses para el test
series1.plot()
series2.plot()
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# Con la fecha

# %%
# %%
train, val = series.split_before(pd.Timestamp("19580101"))
train.plot(label="training")
val.plot(label="validation")
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# Comenzamos con el modelo THETA

# %%
# %%
from darts.models import Theta, FourTheta
from darts.metrics import mape

model =Theta(seasonality_period=12) # Supone Theta 2
model.fit(train)
forecast = model.predict(len(val))
print("model {} obtains MAPE: {:.2f}%".format(model, mape(val, forecast)))
# Out:
# model Theta(seasonality_period=12) obtains MAPE: 8.15%

# %%
# %%
train.plot(label="train")
val.plot(label="true")
forecast.plot(label="prediction")
# Out:
# <Axes: xlabel='Month'>

# %%
# esto se puede hacer con darts pero esto es para ver a lo bruto lo que hace el modelo
# Search for the best theta parameter, by trying 50 different values
thetas = 2- np.linspace(-10, 10, 50) # 50 valores entre -10 y 10 y lo sumo o resto a 2


best_mape = float("inf")
best_theta = 0




for theta in thetas:

    model = Theta(theta)
    model.fit(train)
    pred_theta = model.predict(len(val))
    res = mape(val, pred_theta)

    if res < best_mape:
        best_mape = res
        best_theta = theta

# %%
thetas
# Out:
# array([12.        , 11.59183673, 11.18367347, 10.7755102 , 10.36734694,
#         9.95918367,  9.55102041,  9.14285714,  8.73469388,  8.32653061,
#         7.91836735,  7.51020408,  7.10204082,  6.69387755,  6.28571429,
#         5.87755102,  5.46938776,  5.06122449,  4.65306122,  4.24489796,
#         3.83673469,  3.42857143,  3.02040816,  2.6122449 ,  2.20408163,
#         1.79591837,  1.3877551 ,  0.97959184,  0.57142857,  0.16326531,
#        -0.24489796, -0.65306122, -1.06122449, -1.46938776, -1.87755102,
#        -2.28571429, -2.69387755, -3.10204082, -3.51020408, -3.91836735,
#        -4.32653061, -4.73469388, -5.14285714, -5.55102041, -5.95918367,
#        -6.36734694, -6.7755102 , -7.18367347, -7.59183673, -8.        ])

# %%
best_mape #hemos mejorado el mape en 4% con respecto al modelo inicial
# Out:
# 4.402613465381075

# %%
best_theta
# Out:
# -3.5102040816326543

# %%
# %%
best_theta_model = Theta(best_theta, seasonality_period=12)
best_theta_model.fit(train)
pred_best_theta = best_theta_model.predict(len(val))

print(
    "The MAPE is: {:.2f}, with theta = {}.".format(
        mape(val, pred_best_theta), best_theta
    )
)
# Out:
# The MAPE is: 4.40, with theta = -3.5102040816326543.

# %%
# %%
train.plot(label="train")
val.plot(label="true")
pred_best_theta.plot(label="prediction")
# Out:
# <Axes: xlabel='Month'>

# %%
best_theta_model.model_params
# Out:
# OrderedDict([('theta', -3.5102040816326543),
#              ('seasonality_period', 12),
#              ('season_mode',
#               <SeasonalityMode.MULTIPLICATIVE: 'multiplicative'>)])

# %% [markdown]
# # Modelo 4Theta

# %%
model =FourTheta(seasonality_period=12)
model.fit(train)
forecast = model.predict(len(val))
print("model {} obtains MAPE: {:.2f}%".format(model, mape(val, forecast)))
# Out:
# model FourTheta(seasonality_period=12) obtains MAPE: 8.08%

# %%
# %%
train.plot(label="train")
val.plot(label="true")
forecast.plot(label="prediction")
# Out:
# <Axes: xlabel='Month'>

# %%
from darts.utils.utils import SeasonalityMode, TrendMode, ModelMode
theta_grid = {
    #'theta':2- np.linspace(-10, 10, 10),
    'theta':[-4,-3,-2,-1,1,2,3,4], #no se le puede dar el valor de 0 a theta
    'model_mode': [ModelMode.ADDITIVE,ModelMode.MULTIPLICATIVE],
    'season_mode': [SeasonalityMode.MULTIPLICATIVE,SeasonalityMode.ADDITIVE],
    'trend_mode': [TrendMode.EXPONENTIAL,TrendMode.LINEAR]
}

best_grid_model=FourTheta.gridsearch(parameters=theta_grid,
                                series=train,
                                forecast_horizon=36, # 12
                                start=0.5,
                                last_points_only=False,
                                metric=mape,
                                reduction=np.mean,
                                verbose=False , #lo pongo false porque sino me sale un warning
                                n_jobs=-1)

best_grid_model
# Out:
# (FourTheta(theta=-2, seasonality_period=None, season_mode=SeasonalityMode.MULTIPLICATIVE, model_mode=ModelMode.ADDITIVE, trend_mode=TrendMode.LINEAR, normalization=True),
#  {'theta': -2,
#   'model_mode': <ModelMode.ADDITIVE: 'additive'>,
#   'season_mode': <SeasonalityMode.MULTIPLICATIVE: 'multiplicative'>,
#   'trend_mode': <TrendMode.LINEAR: 'linear'>},
#  9.140683036846676)

# %%
modelo=FourTheta(theta=best_grid_model[1]['theta'],
                 model_mode=ModelMode.ADDITIVE,
                 season_mode=SeasonalityMode.MULTIPLICATIVE,
                 trend_mode=TrendMode.LINEAR
                 )
modelo.fit(train)
pred_modelo = modelo.predict(len(val))

train.plot(label="train")
val.plot(label="true")
pred_modelo.plot(label="prediction")
# Out:
# <Axes: xlabel='Month'>

# %%
print("model {} obtains MAPE: {:.2f}%".format(modelo, mape(val, pred_modelo)))
# deberia ser mejor queel theta pero no sabemos porque no. por eso hayq ue estudiar tantos modelos. no sabemos cual sera el mejor para nuestro dataset
# Out:
# model FourTheta(theta=-2) obtains MAPE: 5.33%

# %%
# %%
train.plot(label="train")
val.plot(label="true")
pred_modelo.plot(label="prediction 4Theta")
pred_best_theta.plot(label="prediction Theta")
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# # Cross Validation: Historical

# %%
# %%
historical_fcast_theta = best_theta_model.historical_forecasts(
    series, start=0.5, forecast_horizon=36, verbose=False, stride=1
)

series.plot(label="data")
historical_fcast_theta.plot(label="backtest 12-months ahead forecast (Theta)")
print("MAPE = {:.2f}%".format(mape(historical_fcast_theta, series)))
# Out:
# MAPE = 3.22%

# %% [markdown]
# ## BackTest

# %%
# %%


raw_errors = best_theta_model.backtest(
    series, 
    start=0.4, 
    forecast_horizon=12, 
    metric=mape, 
    reduction=None, # None: return errors
    verbose=False
)

from darts.utils.statistics import plot_hist

plot_hist(
    raw_errors,
    bins=np.arange(0, max(raw_errors), 1),
    title="Individual backtest error scores (histogram)",
)

# %%
# %%
average_error = best_theta_model.backtest(
    series,
    start=0.4,
    forecast_horizon=12,
    metric=mape,
    reduction=np.mean,  # this is actually the default
    verbose=True,
)

print("Average error (MAPE) over all historical forecasts: %.2f" % average_error)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[74], line 2
#       1 # %%
# ----> 2 average_error = best_theta_model.backtest(
#       3     series,
#       4     start=0.4,
#       5     forecast_horizon=12,
#       6     metric=mape,
#       7     reduction=np.mean,  # this is actually the default
#       8     verbose=True,
#       9 )
#      11 print("Average error (MAPE) over all historical forecasts: %.2f" % average_error)
#
# File /workspaces/TimeSeries/.conda/lib/python3.10/site-packages/darts/models/forecasting/forecasting_model.py:1344, in ForecastingModel.backtest(self, series, past_covariates, future_covariates, historical_forecasts, num_samples, train_length, start, start_format, forecast_horizon, stride, retrain, overlap_end, last_points_only, metric, reduction, verbose, show_warnings, metric_kwargs, fit_kwargs, predict_kwargs)
#    1341 if len(metric_kwargs) != len(metric):
#    1342     metric_kwargs = [metric_kwargs[0] for _ in range(len(metric))]
# -> 1344 historical_forecasts = historical_forecasts or self.historical_forecasts(
#    1345     series=series,
#    1346     past_covariates=past_covariates,
#    1347     future_covariates=future_covariates,
#    1348     num_samples=num_samples,
#    1349     train_length=train_length,
#    1350     start=start,
#    1351     start_format=start_format,
#    1352     forecast_horizon=forecast_horizon,
#    1353     stride=stride,
#    1354     retrain=retrain,
#    1355     overlap_end=overlap_end,
#    1356     last_points_only=last_points_only,
#    1357     verbose=verbose,
#    1358     show_warnings=show_warnings,
#    1359     fit_kwargs=fit_kwargs,
#    1360     predict_kwargs=predict_kwargs,
#    1361 )
#    1363 # remember input series type
#    1364 series_seq_type = get_series_seq_type(series)
#
# File /workspaces/TimeSeries/.conda/lib/python3.10/site-packages/darts/utils/utils.py:143, in _with_sanity_checks.<locals>.decorator.<locals>.sanitized_method(self, *args, **kwargs)
#     140     only_args.pop("self")
#     142     getattr(self, sanity_check_method)(*only_args.values(), **only_kwargs)
# --> 143 return method_to_sanitize(self, *only_args.values(), **only_kwargs)
#
# File /workspaces/TimeSeries/.conda/lib/python3.10/site-packages/darts/models/forecasting/forecasting_model.py:1009, in ForecastingModel.historical_forecasts(self, series, past_covariates, future_covariates, num_samples, train_length, start, start_format, forecast_horizon, stride, retrain, overlap_end, last_points_only, verbose, show_warnings, predict_likelihood_parameters, enable_optimization, fit_kwargs, predict_kwargs)
#    1001 historical_forecasts_time_index = generate_index(
#    1002     start=historical_forecasts_time_index[0],
#    1003     end=historical_forecasts_time_index[-1],
#    1004     freq=series_.freq,
#    1005 )
#    1007 if len(series) == 1:
#    1008     # Only use tqdm if there's no outer loop
# -> 1009     iterator = _build_tqdm_iterator(
#    1010         historical_forecasts_time_index[::stride], verbose
#    1011     )
#    1012 else:
#    1013     iterator = historical_forecasts_time_index[::stride]
#
# File /workspaces/TimeSeries/.conda/lib/python3.10/site-packages/darts/utils/utils.py:75, in _build_tqdm_iterator(iterable, verbose, **kwargs)
#      73 if verbose:
#      74     if _isnotebook():
# ---> 75         iterator = tqdm_notebook(iterable, **kwargs)
#      76     else:
#      77         iterator = tqdm(iterable, **kwargs)
#
# File /workspaces/TimeSeries/.conda/lib/python3.10/site-packages/tqdm/notebook.py:234, in tqdm_notebook.__init__(self, *args, **kwargs)
#     232 unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     233 total = self.total * unit_scale if self.total else self.total
# --> 234 self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     235 self.container.pbar = proxy(self)
#     236 self.displayed = False
#
# File /workspaces/TimeSeries/.conda/lib/python3.10/site-packages/tqdm/notebook.py:108, in tqdm_notebook.status_printer(_, total, desc, ncols)
#      99 # Fallback to text bar if there's no total
#     100 # DEPRECATED: replaced with an 'info' style bar
#     101 # if not total:
#    (...)
#     105
#     106 # Prepare IPython progress bar
#     107 if IProgress is None:  # #187 #451 #558 #872
# --> 108     raise ImportError(WARN_NOIPYW)
#     109 if total:
#     110     pbar = IProgress(min=0, max=total)
#
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
average_error
# Out:
# 7.827396324361945

# %%
raw_errors
# Out:
# [6.5379281293155085,
#  7.371185893726702,
#  5.580456386627105,
#  3.490243073743589,
#  3.345177907426801,
#  8.081784512441583,
#  4.587132580556616,
#  3.913350154796443,
#  10.64311258201373,
#  14.46239422675941,
#  25.231383723542667,
#  3.096056186912415,
#  4.035816329953417,
#  4.59003619858021,
#  4.529220243680979,
#  5.633325855935139,
#  4.439711495777617,
#  6.908807183605649,
#  8.152361332114221,
#  8.776733492845285,
#  4.275579447393355,
#  15.093990533025895,
#  24.811885189555998,
#  2.455907193212323,
#  2.664453206416677,
#  2.7038378913267826,
#  3.3378249776294453,
#  2.3710841239596046,
#  2.314529926726536,
#  3.5400688480895544,
#  3.970323494455949,
#  2.7213230520526084,
#  11.273063780154619,
#  18.23885243201152,
#  25.775234541143515,
#  4.001318302642196,
#  3.272563039503778,
#  3.1989832455968785,
#  3.23415870671536,
#  3.377634084916345,
#  3.393203507664364,
#  5.5747721835296495,
#  4.897451839485512,
#  5.359640162236314,
#  14.328571189065908,
#  22.12210672472015,
#  30.805588003819274,
#  8.758206148864014,
#  7.050796871401413,
#  6.118601344468342,
#  6.987977293933069,
#  5.630699003163164,
#  5.462641556799962,
#  3.7871341130013803,
#  4.119453162627945,
#  4.497477006283645,
#  3.5268359601996773,
#  19.66559445337023,
#  30.65836586983582,
#  8.523608127644993,
#  3.6721319565714166,
#  3.9653459752118216,
#  4.347606602318826,
#  7.030505684771605,
#  4.912165182186133,
#  7.631328661599267,
#  6.065330904672049,
#  5.817204997916633,
#  2.965887773369004,
#  15.272365234094377,
#  27.7912866261043,
#  4.452016471270822,
#  3.384411687553472,
#  3.7097189790939074,
#  3.1475400557688484,
#  3.409715830006314]
