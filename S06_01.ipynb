# %% [markdown]
# # Modelos Theta y 4Theta

# %%
# instalar libreria darts para series de tiempo 
# https://pypi.org/project/darts/
# !pip install darts
# Out:
# Requirement already satisfied: darts in ./.conda/lib/python3.10/site-packages (0.26.0)
# Requirement already satisfied: holidays>=0.11.1 in ./.conda/lib/python3.10/site-packages (from darts) (0.35)
# Requirement already satisfied: joblib>=0.16.0 in /home/codespace/.local/lib/python3.10/site-packages (from darts) (1.3.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/codespace/.local/lib/python3.10/site-packages (from darts) (3.7.3)
# Requirement already satisfied: nfoursid>=1.0.0 in ./.conda/lib/python3.10/site-packages (from darts) (1.0.1)
# Requirement already satisfied: numpy>=1.19.0 in /home/codespace/.local/lib/python3.10/site-packages (from darts) (1.25.2)
# Requirement already satisfied: pmdarima>=1.8.0 in ./.conda/lib/python3.10/site-packages (from darts) (2.0.3)
# Requirement already satisfied: pyod>=0.9.5 in ./.conda/lib/python3.10/site-packages (from darts) (1.1.0)
# Requirement already satisfied: requests>=2.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from darts) (2.31.0)
# Requirement already satisfied: scikit-learn>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from darts) (1.3.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/codespace/.local/lib/python3.10/site-packages (from darts) (1.11.2)
# Requirement already satisfied: shap>=0.40.0 in ./.conda/lib/python3.10/site-packages (from darts) (0.43.0)
# Requirement already satisfied: statsforecast>=1.4 in ./.conda/lib/python3.10/site-packages (from darts) (1.6.0)
# Requirement already satisfied: statsmodels>=0.14.0 in ./.conda/lib/python3.10/site-packages (from darts) (0.14.0)
# Requirement already satisfied: tbats>=1.1.0 in ./.conda/lib/python3.10/site-packages (from darts) (1.1.3)
# Requirement already satisfied: tqdm>=4.60.0 in ./.conda/lib/python3.10/site-packages (from darts) (4.66.1)
# Requirement already satisfied: typing-extensions in /home/codespace/.local/lib/python3.10/site-packages (from darts) (4.7.1)
# Requirement already satisfied: xarray>=0.17.0 in ./.conda/lib/python3.10/site-packages (from darts) (2023.9.0)
# Requirement already satisfied: xgboost>=1.6.0 in ./.conda/lib/python3.10/site-packages (from darts) (2.0.0)
# Requirement already satisfied: pytorch-lightning>=1.5.0 in ./.conda/lib/python3.10/site-packages (from darts) (2.1.0)
# Requirement already satisfied: tensorboardX>=2.1 in ./.conda/lib/python3.10/site-packages (from darts) (2.6.2.2)
# Requirement already satisfied: torch>=1.8.0 in /home/codespace/.local/lib/python3.10/site-packages (from darts) (2.0.1)
# Requirement already satisfied: pandas>=1.0.5 in /home/codespace/.local/lib/python3.10/site-packages (from darts) (2.1.0)
# Requirement already satisfied: python-dateutil in /home/codespace/.local/lib/python3.10/site-packages (from holidays>=0.11.1->darts) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.3.0->darts) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.3.0->darts) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.3.0->darts) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.3.0->darts) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.3.0->darts) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.3.0->darts) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.3.0->darts) (3.1.1)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=1.0.5->darts) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=1.0.5->darts) (2023.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in ./.conda/lib/python3.10/site-packages (from pmdarima>=1.8.0->darts) (3.0.3)
# Requirement already satisfied: urllib3 in /home/codespace/.local/lib/python3.10/site-packages (from pmdarima>=1.8.0->darts) (2.0.4)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /home/codespace/.local/lib/python3.10/site-packages (from pmdarima>=1.8.0->darts) (68.0.0)
# Requirement already satisfied: numba>=0.51 in ./.conda/lib/python3.10/site-packages (from pyod>=0.9.5->darts) (0.58.0)
# Requirement already satisfied: six in /home/codespace/.local/lib/python3.10/site-packages (from pyod>=0.9.5->darts) (1.16.0)
# Requirement already satisfied: PyYAML>=5.4 in /home/codespace/.local/lib/python3.10/site-packages (from pytorch-lightning>=1.5.0->darts) (6.0.1)
# Requirement already satisfied: fsspec[http]>2021.06.0 in ./.conda/lib/python3.10/site-packages (from pytorch-lightning>=1.5.0->darts) (2023.9.2)
# Requirement already satisfied: torchmetrics>=0.7.0 in ./.conda/lib/python3.10/site-packages (from pytorch-lightning>=1.5.0->darts) (1.2.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in ./.conda/lib/python3.10/site-packages (from pytorch-lightning>=1.5.0->darts) (0.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.22.0->darts) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.22.0->darts) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.22.0->darts) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-learn>=1.0.1->darts) (3.2.0)
# Requirement already satisfied: slicer==0.0.7 in ./.conda/lib/python3.10/site-packages (from shap>=0.40.0->darts) (0.0.7)
# Requirement already satisfied: cloudpickle in ./.conda/lib/python3.10/site-packages (from shap>=0.40.0->darts) (3.0.0)
# Requirement already satisfied: polars in ./.conda/lib/python3.10/site-packages (from statsforecast>=1.4->darts) (0.19.8)
# Requirement already satisfied: fugue>=0.8.1 in ./.conda/lib/python3.10/site-packages (from statsforecast>=1.4->darts) (0.8.6)
# Requirement already satisfied: patsy>=0.5.2 in ./.conda/lib/python3.10/site-packages (from statsmodels>=0.14.0->darts) (0.5.3)
# Requirement already satisfied: protobuf>=3.20 in ./.conda/lib/python3.10/site-packages (from tensorboardX>=2.1->darts) (4.24.4)
# Requirement already satisfied: filelock in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.8.0->darts) (3.12.4)
# Requirement already satisfied: sympy in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.8.0->darts) (1.12)
# Requirement already satisfied: networkx in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.8.0->darts) (3.1)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.8.0->darts) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.8.0->darts) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.8.0->darts) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.8.0->darts) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.8.0->darts) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.8.0->darts) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.8.0->darts) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.8.0->darts) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.8.0->darts) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.8.0->darts) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.8.0->darts) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.8.0->darts) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from torch>=1.8.0->darts) (2.0.0)
# Requirement already satisfied: wheel in /home/codespace/.local/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.8.0->darts) (0.41.2)
# Requirement already satisfied: cmake in /home/codespace/.local/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.8.0->darts) (3.27.4.1)
# Requirement already satisfied: lit in /home/codespace/.local/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.8.0->darts) (16.0.6)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in ./.conda/lib/python3.10/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (3.8.6)
# Requirement already satisfied: triad>=0.9.1 in ./.conda/lib/python3.10/site-packages (from fugue>=0.8.1->statsforecast>=1.4->darts) (0.9.1)
# Requirement already satisfied: adagio>=0.2.4 in ./.conda/lib/python3.10/site-packages (from fugue>=0.8.1->statsforecast>=1.4->darts) (0.2.4)
# Requirement already satisfied: pyarrow>=0.15.1 in ./.conda/lib/python3.10/site-packages (from fugue>=0.8.1->statsforecast>=1.4->darts) (13.0.0)
# Requirement already satisfied: qpd>=0.4.4 in ./.conda/lib/python3.10/site-packages (from fugue>=0.8.1->statsforecast>=1.4->darts) (0.4.4)
# Requirement already satisfied: fugue-sql-antlr>=0.1.6 in ./.conda/lib/python3.10/site-packages (from fugue>=0.8.1->statsforecast>=1.4->darts) (0.1.7)
# Requirement already satisfied: sqlglot in ./.conda/lib/python3.10/site-packages (from fugue>=0.8.1->statsforecast>=1.4->darts) (18.13.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in ./.conda/lib/python3.10/site-packages (from numba>=0.51->pyod>=0.9.5->darts) (0.41.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->darts) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/codespace/.local/lib/python3.10/site-packages (from sympy->torch>=1.8.0->darts) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/codespace/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in ./.conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts) (1.3.1)
# Requirement already satisfied: antlr4-python3-runtime<4.12,>=4.11.1 in ./.conda/lib/python3.10/site-packages (from fugue-sql-antlr>=0.1.6->fugue>=0.8.1->statsforecast>=1.4->darts) (4.11.1)
# Requirement already satisfied: fs in ./.conda/lib/python3.10/site-packages (from triad>=0.9.1->fugue>=0.8.1->statsforecast>=1.4->darts) (2.4.16)
# Requirement already satisfied: appdirs~=1.4.3 in ./.conda/lib/python3.10/site-packages (from fs->triad>=0.9.1->fugue>=0.8.1->statsforecast>=1.4->darts) (1.4.4)

# %% [markdown]
# # Modelos Theta

# %%
# 
import os, sys
from google.colab import drive
drive.mount('/content/mnt', force_remount=True)
nb_path = '/content/notebooks'
os.symlink('/content/mnt/My Drive/Colab Notebooks/Librerias', nb_path)
#sys.path.insert(0, nb_path)  # or append(nb_path)
sys.path.append(nb_path)  # or append(nb_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /workspaces/TimeSeries/S06_01.ipynb Cell 4 line 3
#       <a href='vscode-notebook-cell://codespaces%2Bredesigned-carnival-69gxpj9rqw77c5rrx/workspaces/TimeSeries/S06_01.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> #
#       <a href='vscode-notebook-cell://codespaces%2Bredesigned-carnival-69gxpj9rqw77c5rrx/workspaces/TimeSeries/S06_01.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> import os, sys
# ----> <a href='vscode-notebook-cell://codespaces%2Bredesigned-carnival-69gxpj9rqw77c5rrx/workspaces/TimeSeries/S06_01.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> from google.colab import drive
#       <a href='vscode-notebook-cell://codespaces%2Bredesigned-carnival-69gxpj9rqw77c5rrx/workspaces/TimeSeries/S06_01.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> drive.mount('/content/mnt', force_remount=True)
#       <a href='vscode-notebook-cell://codespaces%2Bredesigned-carnival-69gxpj9rqw77c5rrx/workspaces/TimeSeries/S06_01.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> nb_path = '/content/notebooks'
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Es necesario tener instalado DARTS
#
# [Darts: https://unit8co.github.io/darts/index.html](https://unit8co.github.io/darts/index.html)

# %%
#!pip install darts

# %%
# Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - Utilizamos la libreria **darts**
# - Seleccionamos los datos de Lineas aereas

# %%
# %%
from darts import TimeSeries
from darts.datasets import AirPassengersDataset

# %% [markdown]
# - **Grafico de la Serie Temporal de lineas aereas**

# %%
# %%
series = AirPassengersDataset().load()
series
# Out:
# <TimeSeries (DataArray) (Month: 144, component: 1, sample: 1)>
# array([[[112.]],
#
#        [[118.]],
#
#        [[132.]],
#
#        [[129.]],
#
#        [[121.]],
#
#        [[135.]],
#
#        [[148.]],
#
#        [[148.]],
#
#        [[136.]],
#
#        [[119.]],
#
# ...
#
#        [[419.]],
#
#        [[461.]],
#
#        [[472.]],
#
#        [[535.]],
#
#        [[622.]],
#
#        [[606.]],
#
#        [[508.]],
#
#        [[461.]],
#
#        [[390.]],
#
#        [[432.]]])
# Coordinates:
#   * Month      (Month) datetime64[ns] 1949-01-01 1949-02-01 ... 1960-12-01
#   * component  (component) object '#Passengers'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %%
#import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (12,6)
series.plot()
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# - Diferentes formas de seleccionat TRAIN y TEST

# %% [markdown]
# ```
# split_before
# ```

# %%
# %%
series1, series2 = series.split_before(0.75) # 75% train, 25% test
series1.plot()
series2.plot()
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# - Con el número de observaciones

# %%
# %%
series1, series2 = series[:-36], series[-36:] #cojo los ultimos 36 meses para el test
series1.plot()
series2.plot()
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# Con la fecha

# %%
# %%
train, val = series.split_before(pd.Timestamp("19580101"))
train.plot(label="training")
val.plot(label="validation")
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# Comenzamos con el modelo THETA

# %%
# %%
from darts.models import Theta, FourTheta
from darts.metrics import mape

model =Theta(seasonality_period=12) # Supone Theta 2
model.fit(train)
forecast = model.predict(len(val))
print("model {} obtains MAPE: {:.2f}%".format(model, mape(val, forecast)))
# Out:
# model Theta(seasonality_period=12) obtains MAPE: 8.15%

# %%
# %%
train.plot(label="train")
val.plot(label="true")
forecast.plot(label="prediction")
# Out:
# <Axes: xlabel='Month'>

# %%
# esto se puede hacer con darts pero esto es para ver a lo bruto lo que hace el modelo
# Search for the best theta parameter, by trying 50 different values
thetas = 2- np.linspace(-10, 10, 50) # 50 valores entre -10 y 10 y lo sumo o resto a 2


best_mape = float("inf")
best_theta = 0




for theta in thetas:

    model = Theta(theta)
    model.fit(train)
    pred_theta = model.predict(len(val))
    res = mape(val, pred_theta)

    if res < best_mape:
        best_mape = res
        best_theta = theta

# %%
thetas
# Out:
# array([12.        , 11.59183673, 11.18367347, 10.7755102 , 10.36734694,
#         9.95918367,  9.55102041,  9.14285714,  8.73469388,  8.32653061,
#         7.91836735,  7.51020408,  7.10204082,  6.69387755,  6.28571429,
#         5.87755102,  5.46938776,  5.06122449,  4.65306122,  4.24489796,
#         3.83673469,  3.42857143,  3.02040816,  2.6122449 ,  2.20408163,
#         1.79591837,  1.3877551 ,  0.97959184,  0.57142857,  0.16326531,
#        -0.24489796, -0.65306122, -1.06122449, -1.46938776, -1.87755102,
#        -2.28571429, -2.69387755, -3.10204082, -3.51020408, -3.91836735,
#        -4.32653061, -4.73469388, -5.14285714, -5.55102041, -5.95918367,
#        -6.36734694, -6.7755102 , -7.18367347, -7.59183673, -8.        ])

# %%
best_mape #hemos mejorado el mape en 4% con respecto al modelo inicial
# Out:
# 4.402613465381075

# %%
best_theta
# Out:
# -3.5102040816326543

# %%
# %%
best_theta_model = Theta(best_theta, seasonality_period=12)
best_theta_model.fit(train)
pred_best_theta = best_theta_model.predict(len(val))

print(
    "The MAPE is: {:.2f}, with theta = {}.".format(
        mape(val, pred_best_theta), best_theta
    )
)
# Out:
# The MAPE is: 4.40, with theta = -3.5102040816326543.

# %%
# %%
train.plot(label="train")
val.plot(label="true")
pred_best_theta.plot(label="prediction")
# Out:
# <Axes: xlabel='Month'>

# %%
best_theta_model.model_params
# Out:
# OrderedDict([('theta', -3.5102040816326543),
#              ('seasonality_period', None),
#              ('season_mode',
#               <SeasonalityMode.MULTIPLICATIVE: 'multiplicative'>)])

# %% [markdown]
# # Modelo 4Theta

# %%
model =FourTheta(seasonality_period=12)
model.fit(train)
forecast = model.predict(len(val))
print("model {} obtains MAPE: {:.2f}%".format(model, mape(val, forecast)))
# Out:
# model FourTheta(seasonality_period=12) obtains MAPE: 8.08%

# %%
# %%
train.plot(label="train")
val.plot(label="true")
forecast.plot(label="prediction")
# Out:
# <Axes: xlabel='Month'>

# %%
from darts.utils.utils import SeasonalityMode, TrendMode, ModelMode
theta_grid = {
    #'theta':2- np.linspace(-10, 10, 10),
    'theta':[-4,-3,-2,-1,1,2,3,4], #no se le puede dar el valor de 0 a theta
    'model_mode': [ModelMode.ADDITIVE,ModelMode.MULTIPLICATIVE],
    'season_mode': [SeasonalityMode.MULTIPLICATIVE,SeasonalityMode.ADDITIVE],
    'trend_mode': [TrendMode.EXPONENTIAL,TrendMode.LINEAR]
}

best_grid_model=FourTheta.gridsearch(parameters=theta_grid,
                                series=train,
                                forecast_horizon=36, # 12
                                start=0.5,
                                last_points_only=False,
                                metric=mape,
                                reduction=np.mean,
                                verbose=False , #lo pongo false porque sino me sale un warning
                                n_jobs=-1)

best_grid_model
# Out:
# (FourTheta(theta=-2, seasonality_period=None, season_mode=SeasonalityMode.MULTIPLICATIVE, model_mode=ModelMode.ADDITIVE, trend_mode=TrendMode.LINEAR, normalization=True),
#  {'theta': -2,
#   'model_mode': <ModelMode.ADDITIVE: 'additive'>,
#   'season_mode': <SeasonalityMode.MULTIPLICATIVE: 'multiplicative'>,
#   'trend_mode': <TrendMode.LINEAR: 'linear'>},
#  9.140683036846674)

# %%
# update jupyter and ipywidgets
# !pip install -U jupyter ipywidgets
# Out:
# Requirement already satisfied: jupyter in ./.conda/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: ipywidgets in ./.conda/lib/python3.10/site-packages (8.1.1)
# Requirement already satisfied: notebook in ./.conda/lib/python3.10/site-packages (from jupyter) (7.0.6)
# Requirement already satisfied: qtconsole in ./.conda/lib/python3.10/site-packages (from jupyter) (5.4.4)
# Requirement already satisfied: jupyter-console in ./.conda/lib/python3.10/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /home/codespace/.local/lib/python3.10/site-packages (from jupyter) (7.8.0)
# Requirement already satisfied: ipykernel in /home/codespace/.local/lib/python3.10/site-packages (from jupyter) (6.25.2)
# Requirement already satisfied: comm>=0.1.3 in /home/codespace/.local/lib/python3.10/site-packages (from ipywidgets) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from ipywidgets) (8.15.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in ./.conda/lib/python3.10/site-packages (from ipywidgets) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in ./.conda/lib/python3.10/site-packages (from ipywidgets) (3.0.9)
# Requirement already satisfied: backcall in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.0)
# Requirement already satisfied: matplotlib-inline in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: pickleshare in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.16.1)
# Requirement already satisfied: stack-data in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: exceptiongroup in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.3)
# Requirement already satisfied: pexpect>4.3 in /home/codespace/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: debugpy>=1.6.5 in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel->jupyter) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel->jupyter) (8.3.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel->jupyter) (5.3.1)
# Requirement already satisfied: nest-asyncio in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel->jupyter) (1.5.7)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel->jupyter) (23.1)
# Requirement already satisfied: psutil in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel->jupyter) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel->jupyter) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in /home/codespace/.local/lib/python3.10/site-packages (from ipykernel->jupyter) (6.3.3)
# Requirement already satisfied: beautifulsoup4 in /home/codespace/.local/lib/python3.10/site-packages (from nbconvert->jupyter) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from nbconvert->jupyter) (6.0.0)
# Requirement already satisfied: defusedxml in /home/codespace/.local/lib/python3.10/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /home/codespace/.local/lib/python3.10/site-packages (from nbconvert->jupyter) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in /home/codespace/.local/lib/python3.10/site-packages (from nbconvert->jupyter) (0.2.2)
# Requirement already satisfied: markupsafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from nbconvert->jupyter) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/codespace/.local/lib/python3.10/site-packages (from nbconvert->jupyter) (3.0.1)
# Requirement already satisfied: nbclient>=0.5.0 in /home/codespace/.local/lib/python3.10/site-packages (from nbconvert->jupyter) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in /home/codespace/.local/lib/python3.10/site-packages (from nbconvert->jupyter) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/codespace/.local/lib/python3.10/site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: tinycss2 in /home/codespace/.local/lib/python3.10/site-packages (from nbconvert->jupyter) (1.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/codespace/.local/lib/python3.10/site-packages (from notebook->jupyter) (2.7.3)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /home/codespace/.local/lib/python3.10/site-packages (from notebook->jupyter) (2.25.0)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in /home/codespace/.local/lib/python3.10/site-packages (from notebook->jupyter) (4.0.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/codespace/.local/lib/python3.10/site-packages (from notebook->jupyter) (0.2.3)
# Requirement already satisfied: ipython-genutils in ./.conda/lib/python3.10/site-packages (from qtconsole->jupyter) (0.2.0)
# Requirement already satisfied: qtpy>=2.4.0 in ./.conda/lib/python3.10/site-packages (from qtconsole->jupyter) (2.4.0)
# Requirement already satisfied: six>=1.9.0 in /home/codespace/.local/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (1.16.0)
# Requirement already satisfied: webencodings in /home/codespace/.local/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/codespace/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (3.10.0)
# Requirement already satisfied: anyio>=3.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (4.0.0)
# Requirement already satisfied: argon2-cffi in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.7.0)
# Requirement already satisfied: jupyter-server-terminals in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.4.4)
# Requirement already satisfied: overrides in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (7.4.0)
# Requirement already satisfied: prometheus-client in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.17.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.17.1)
# Requirement already satisfied: websocket-client in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.6.3)
# Requirement already satisfied: async-lru>=1.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter) (2.2.0)
# Requirement already satisfied: tomli in /home/codespace/.local/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter) (2.0.1)
# Requirement already satisfied: babel>=2.10 in /home/codespace/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.12.1)
# Requirement already satisfied: json5>=0.9.0 in /home/codespace/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.9.14)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/codespace/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (4.19.0)
# Requirement already satisfied: requests>=2.31 in /home/codespace/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.31.0)
# Requirement already satisfied: fastjsonschema in /home/codespace/.local/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.18.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/codespace/.local/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/codespace/.local/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: soupsieve>1.2 in /home/codespace/.local/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: executing>=1.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.0)
# Requirement already satisfied: pure-eval in /home/codespace/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: idna>=2.8 in /home/codespace/.local/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /home/codespace/.local/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from async-lru>=1.0.0->jupyterlab<5,>=4.0.2->notebook->jupyter) (4.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.10.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2023.7.22)
# Requirement already satisfied: argon2-cffi-bindings in /home/codespace/.local/lib/python3.10/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter) (21.2.0)
# Requirement already satisfied: fqdn in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.4)
# Requirement already satisfied: uri-template in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.15.1)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /home/codespace/.local/lib/python3.10/site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.2.3)

# %%
modelo=FourTheta(theta=best_grid_model[1]['theta'],
                 model_mode=ModelMode.ADDITIVE,
                 season_mode=SeasonalityMode.MULTIPLICATIVE,
                 trend_mode=TrendMode.LINEAR
                 )
modelo.fit(train)
pred_modelo = modelo.predict(len(val))

train.plot(label="train")
val.plot(label="true")
pred_modelo.plot(label="prediction")
# Out:
# <Axes: xlabel='Month'>

# %%
print("model {} obtains MAPE: {:.2f}%".format(modelo, mape(val, pred_modelo)))
# deberia ser mejor queel theta pero no sabemos porque no. por eso hayq ue estudiar tantos modelos. no sabemos cual sera el mejor para nuestro dataset
# Out:
# model FourTheta(theta=-2) obtains MAPE: 5.33%

# %%
# %%
train.plot(label="train")
val.plot(label="true")
pred_modelo.plot(label="prediction 4Theta")
pred_best_theta.plot(label="prediction Theta")
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# # Cross Validation: Historical

# %%
# %%
historical_fcast_theta = best_theta_model.historical_forecasts(
    series, start=0.5, forecast_horizon=36, verbose=True, stride=1
)

series.plot(label="data")
historical_fcast_theta.plot(label="backtest 12-months ahead forecast (Theta)")
print("MAPE = {:.2f}%".format(mape(historical_fcast_theta, series)))
# Out:
#   0%|          | 0/38 [00:00<?, ?it/s]
# MAPE = 4.68%

# %% [markdown]
# ## BackTest

# %%
# %%


raw_errors = best_theta_model.backtest(
    series, 
    start=0.4, 
    forecast_horizon=12, 
    metric=mape, 
    reduction=None, # None: return errors
    verbose=True
)

from darts.utils.statistics import plot_hist

plot_hist(
    raw_errors,
    bins=np.arange(0, max(raw_errors), 1),
    title="Individual backtest error scores (histogram)",
)
# Out:
#   0%|          | 0/76 [00:00<?, ?it/s]

# %%
# %%
average_error = best_theta_model.backtest(
    series,
    start=0.4,
    forecast_horizon=12,
    metric=mape,
    reduction=np.mean,  # this is actually the default
    verbose=True,
)

print("Average error (MAPE) over all historical forecasts: %.2f" % average_error)
# Out:
#   0%|          | 0/76 [00:00<?, ?it/s]
#   5%|▌         | 4/76 [00:00<00:02, 35.66it/s]
#  11%|█         | 8/76 [00:00<00:02, 33.68it/s]
#  16%|█▌        | 12/76 [00:00<00:01, 33.50it/s]
#  21%|██        | 16/76 [00:00<00:01, 32.01it/s]
#  26%|██▋       | 20/76 [00:00<00:01, 31.04it/s]
#  32%|███▏      | 24/76 [00:00<00:01, 31.34it/s]
#  37%|███▋      | 28/76 [00:00<00:01, 31.67it/s]
#  42%|████▏     | 32/76 [00:00<00:01, 32.10it/s]
#  47%|████▋     | 36/76 [00:01<00:01, 32.42it/s]
#  53%|█████▎    | 40/76 [00:01<00:01, 32.04it/s]
#  58%|█████▊    | 44/76 [00:01<00:01, 31.26it/s]
#  63%|██████▎   | 48/76 [00:01<00:00, 31.41it/s]
#  68%|██████▊   | 52/76 [00:01<00:00, 30.99it/s]
#  74%|███████▎  | 56/76 [00:01<00:00, 30.85it/s]
#  79%|███████▉  | 60/76 [00:01<00:00, 31.10it/s]
#  84%|████████▍ | 64/76 [00:02<00:00, 29.31it/s]
#  88%|████████▊ | 67/76 [00:02<00:00, 29.40it/s]
#  92%|█████████▏| 70/76 [00:02<00:00, 29.31it/s]
#  96%|█████████▌| 73/76 [00:02<00:00, 29.09it/s]
# 100%|██████████| 76/76 [00:02<00:00, 30.71it/s]
# Average error (MAPE) over all historical forecasts: 7.83

# %%
average_error
# Out:
# 7.827396324361945

# %%
raw_errors
# Out:
# [6.5379281293155085,
#  7.371185893726702,
#  5.580456386627105,
#  3.490243073743589,
#  3.345177907426801,
#  8.081784512441583,
#  4.587132580556616,
#  3.913350154796443,
#  10.64311258201373,
#  14.46239422675941,
#  25.231383723542667,
#  3.096056186912415,
#  4.035816329953417,
#  4.59003619858021,
#  4.529220243680979,
#  5.633325855935139,
#  4.439711495777617,
#  6.908807183605649,
#  8.152361332114221,
#  8.776733492845285,
#  4.275579447393355,
#  15.093990533025895,
#  24.811885189555998,
#  2.455907193212323,
#  2.664453206416677,
#  2.7038378913267826,
#  3.3378249776294453,
#  2.3710841239596046,
#  2.314529926726536,
#  3.5400688480895544,
#  3.970323494455949,
#  2.7213230520526084,
#  11.273063780154619,
#  18.23885243201152,
#  25.775234541143515,
#  4.001318302642196,
#  3.272563039503778,
#  3.1989832455968785,
#  3.23415870671536,
#  3.377634084916345,
#  3.393203507664364,
#  5.5747721835296495,
#  4.897451839485512,
#  5.359640162236314,
#  14.328571189065908,
#  22.12210672472015,
#  30.805588003819274,
#  8.758206148864014,
#  7.050796871401413,
#  6.118601344468342,
#  6.987977293933069,
#  5.630699003163164,
#  5.462641556799962,
#  3.7871341130013803,
#  4.119453162627945,
#  4.497477006283645,
#  3.5268359601996773,
#  19.66559445337023,
#  30.65836586983582,
#  8.523608127644993,
#  3.6721319565714166,
#  3.9653459752118216,
#  4.347606602318826,
#  7.030505684771605,
#  4.912165182186133,
#  7.631328661599267,
#  6.065330904672049,
#  5.817204997916633,
#  2.965887773369004,
#  15.272365234094377,
#  27.7912866261043,
#  4.452016471270822,
#  3.384411687553472,
#  3.7097189790939074,
#  3.1475400557688484,
#  3.409715830006314]
